# %% [markdown]
# # What we mapped

# %% [markdown]
# With this notebook, and with [QGIS TimeManager plug-in](https://plugins.qgis.org/plugins/timemanager/), you will be able to create animated gif and movie to illustrate the work accomplished during a Mapathon event.

# %% [markdown]
# # Configuration

# %% [markdown]
# ## Import libraries

# %%
## Import libraries needed for setting parameters of operating system 
import os
import sys

## Import library for temporary files creation 
import tempfile 

## Import Numpy library
import numpy as np

## Import Psycopg2 library (interection with postgres database)
import psycopg2 as pg

## Import Pandas library (View and manipulaiton of tables)
import pandas as pd

# %% [markdown]
# ## User inputs

# %%
## Define a empty dictionnary for saving user inputs
user={}

# %%
## Enter the name of the new postgresqgl database
user["dbname"] = "Mapathon"
## Enter the postgresqgl username
user["user"] = "tais"
## Enter postgresqgl Password
user["password"] = "tais"
## Enter postgresqgl host
user["host"] = "localhost"
## Enter DB port
user["port"] = "5432"
## Enter postgresqgl schema
user["schema"] = "belgianmapath2018"

# %% [markdown]
# Here after:
# - Enter the path to the main directory of Postgresql.

# %%
## Enter the path to the osm2pgsql folder
user["pgsqlfolder"]="/Library/PostgreSQL/9.6/bin"
## Add environment variables for Postgresql
os.environ['PATH'] = user["pgsqlfolder"] + os.pathsep + os.environ['PATH']

# %% [markdown]
# Here after:
# - Enter the path to the directory where osm2pgsql in located.
# The command-line based program "osm2pgsql" have to be installed on your computer. See [the official wiki page](http://wiki.openstreetmap.org/wiki/Osm2pgsql) for more information. For Windows user, you have to [dowload the osm2pgsql executable](https://ci.appveyor.com/project/openstreetmap/osm2pgsql/history). Go to the page and find the latest 'artifact'.

# %%
## Enter the path to the osm2pgsql folder
user["osm2pgsqlfolder"]="/usr/local/Cellar/osm2pgsql/0.94.0_3"
## Add environment variables for osm2pgsql
os.environ['PATH'] = user["osm2pgsqlfolder"] + os.pathsep + os.environ['PATH']

# %%
# Define the path to the osm2pgsql default.style file
user["stylefile"]="/Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/default_OSMmetadata.style"

# %% [markdown]
# Here after:
# - Enter the path to the folder where the .osm file covering your area of interest will be downloaded.
# OSM data downloading is automated in this script. In case you would manage yourself the retrieving of OSM data, please read the [official wiki page](http://wiki.openstreetmap.org/wiki/Downloading_data) for that purpose. In that case some parts of this notebook should be adapted.

# %%
## Enter the path to the folder where the .osm file will be downloaded
user["osmfolder"]="/Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/Mapathon2018_belgiumuni"
## Enter the prefix you want to be used in the PostGIS DB
user["prefixosm"]="osm"

# %% [markdown]
# Here after:
# - Enter the path to a .shp file (a single polygon feature) corresponding to the area of interest (AOI) which has been mapped. Please, be sure the projection is EPSG 3857.

# %%
## Enter the path to the .shp file corresponding to the area of interested which has been mapped
user["aoi_geojson"]="/Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/4318.geoJSON"
user["aoi_shp"]=os.path.splitext(user["aoi_geojson"])[0]+".shp"

# %%
import geopandas
gdf=geopandas.read_file(user["aoi_geojson"])
gdf.to_file(user["aoi_shp"])

# %% [markdown]
# Here after:
# - Enter the path to .shp files where the resulting osm layer will be saved.

# %%
## Enter the path to the .shp file where the resulting osm layer will be saved - Path for LINES
user["output_lineshp"]="/Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/Mapathon2018_belgiumuni/output_line.shp"

# %%
## Enter the path to the .shp file where the resulting osm layer will be saved - Path for POLYGONS
user["output_polygonshp"]="/Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/Mapathon2018_belgiumuni/output_polygon.shp"

# %% [markdown]
# Here after:
# - Postgresql tables' name are saved as variables. You could change it only if you want.

# %%
## Save postgresqgl table's mane
user["aoi"] = "aoi"
user["bbox"] = "bbox"
user["bbox_coord"] = "bbox_coord"

# %% [markdown]
# **-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-**

# %% [markdown]
# # Import data in Postgis

# %% [markdown]
# ## Create postgis extension

# %% [markdown]
# Postgis extension will be created if it doesn't exists!

# %% [markdown]
# ## Import AOI shapefile

# %% [markdown]
# The following part use the "shp2pgsql" program which should normally already be installed since postgis extension have been created in postgresql. See [this quick guide](http://www.bostongis.com/pgsql2shp_shp2pgsql_quickguide.bqg) for more information.
#
# Fist, a bash file is created according to user parameters. Then, the bash.dat file is pass in an embedded command prompt.

# %%
from subprocess import Popen, PIPE, STDOUT
p = Popen(['shp2pgsql','-s','3857','-d','-I',user["aoi_shp"],user["schema"]+"."+user["aoi"],
           "|","psql","-d",user["dbname"],'-h',user["host"],'-U',user["user"]], stdout=PIPE, stdin=PIPE, stderr=STDOUT)    
bash_stdout = p.communicate(input=user["password"])[0]
print(bash_stdout.decode())
# Out:
# Shapefile type: Polygon
# Postgis type: MULTIPOLYGON[2]
# SET CLIENT_ENCODING TO UTF8;
# SET STANDARD_CONFORMING_STRINGS TO ON;
# SELECT DropGeometryColumn('belgianmapath2018','aoi','geom');
# DROP TABLE IF EXISTS "belgianmapath2018"."aoi";
# BEGIN;
# CREATE TABLE "belgianmapath2018"."aoi" (gid serial,
# "fid" float8);
# ALTER TABLE "belgianmapath2018"."aoi" ADD PRIMARY KEY (gid);
# SELECT AddGeometryColumn('belgianmapath2018','aoi','geom','3857','MULTIPOLYGON',2);
# INSERT INTO "belgianmapath2018"."aoi" ("fid",geom) VALUES ('0','...');
# CREATE INDEX ON "belgianmapath2018"."aoi" USING GIST ("geom");
# COMMIT;
# ANALYZE "belgianmapath2018"."aoi";

# %% [markdown]
# #### Update the PostGis tables nearly creadted to ensure all geometries are valid

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# Query
query="UPDATE "+user["schema"]+"."+user["aoi"]+" \
SET geom = ST_Transform(ST_Multi(ST_CollectionExtract(ST_MakeValid(geom), 3)),3857) \
WHERE ST_IsValid(geom) is not True"
# Execute the CREATE TABLE query 
cur.execute(query)
# Make the changes to the database persistent
db.commit()
    
# Close cursor and communication with the database
cur.close()
db.close()

# %% [markdown]
# **-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-**

# %% [markdown]
# ## Create the bounding box (bbox) of the AOI

# %%
# Connect to the database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# %%
# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS "+user["schema"]+"."+user["bbox"])
# Make the changes to the database persistent
db.commit()

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# Subquery1 
subquery1="SELECT ST_Envelope(geom) as the_geom FROM "+user["schema"]+"."+user["aoi"]

# Save the previous subquery results in a new table
query="CREATE TABLE "+user["schema"]+"."+user["bbox"]+" AS ("
query+=subquery1+")"

# Execute the query 
cur.execute(query)
# Make the changes to the database persistent
db.commit()
# Close cursor and communication with the database
cur.close()
db.close()

# %% [markdown]
# ## Get upper, lower, right and left coordinates of the bbox (in WGS84).

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# %%
# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS "+user["schema"]+"."+user["bbox_coord"])
# Make the changes to the database persistent
db.commit()

# %%
### Save the previous subquery1 results in a new table
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

subquery1="WITH \
wgs84geom AS(\
SELECT  ST_Transform(the_geom, 4326) AS the_geom \
FROM "+user["schema"]+"."+user["bbox"]+") \
\
SELECT ST_Xmin(the_geom) AS west, ST_Xmax(the_geom) AS east, \
ST_Ymin(the_geom) AS south, ST_Ymax(the_geom) AS north \
FROM wgs84geom"

# Query
query="CREATE TABLE "+user["schema"]+"."+user["bbox_coord"]+" AS ("
query+=subquery1+")"

# Execute the CREATE TABLE query 
cur.execute(query)
# Make the changes to the database persistent
db.commit()
# Close cursor and communication with the database
cur.close()
db.close()

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="SELECT * FROM "+user["schema"]+"."+user["bbox_coord"]+" \
LIMIT "+str(nbrow)
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#       west      east     south     north
# 0  6.17157  6.462708  8.427546  9.704996

# %%
## Save coordinates in variables
north_coord=round(df_bbox_coord.loc[0,['north']],6)
south_coord=round(df_bbox_coord.loc[0,['south']],6)
west_coord=round(df_bbox_coord.loc[0,['west']],6)
east_coord=round(df_bbox_coord.loc[0,['east']],6)

# %% [markdown]
# **-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-**

# %% [markdown]
# # Download OpenStreetMap data using Xapi

# %% [markdown]
# Here after, the OpenStreetMap (OSM) data will be downloaded for the AOI. For this prupose, OSM Xapi is used. Please read [this page](http://wiki.openstreetmap.org/wiki/Xapi) or [this one](http://wiki.openstreetmap.org/wiki/Overpass_API/XAPI_Compatibility_Layer) for extra information on Xapi. Please notice that the '@meta' is important to download informations about the osm features (last user, timestamp). Osm2pgsql use a .style file which manage how to osm data will be uploaded in the Postgis database. Please use [this .style file](https://github.com/tgrippa/Mapathon_HOT_OSM_WhatWeMapped/blob/master/default_OSMmetadata.style) wich allow to upload the metadata correctly.

# %%
import urllib

## Create the Xapi URL to download the data
print "OSM data will be downloaded for bbox (W:"+str(west_coord)+" S:"+str(south_coord)+" E:"+str(east_coord)+" N:"+str(north_coord)+")"

osm_api_base_url="http://www.overpass-api.de/api/xapi?*"
osm_api_url=osm_api_base_url+"[bbox="+str(west_coord)+","+str(south_coord)+","+str(east_coord)+","+str(north_coord)+"][@meta]"

osm_file=user["osmfolder"]+"/"+user["prefixosm"]+".osm"

## Retrieve the .osm file with the URL
urllib.urlretrieve (osm_api_url, osm_file)
print osm_api_url
# Out:
# OSM data will be downloaded for bbox (W:6.17157 S:8.427546 E:6.462708 N:9.704996)
# http://www.overpass-api.de/api/xapi?*[bbox=6.17157,8.427546,6.462708,9.704996][@meta]

# %% [markdown]
# # Import OSM layers in PostGis database

# %%
## Makes a 5sec stop in the process
import time
time.sleep(5)

## Build the osm2pgsql command-line
cmdline=""
cmdline+="osm2pgsql -c -d "+user["dbname"]+" " 
cmdline+="-W "+" "
cmdline+="-U "+user["user"]+" "
cmdline+="-H "+user["host"]+" "
cmdline+="--extra-attributes"+" "
cmdline+="-p "+user["prefixosm"]+" "
cmdline+="-S "+user["stylefile"]+" "
cmdline+=user["osmfolder"]+"/"+user["prefixosm"]+".osm"

## Create temp bash file for osm2pgsql
outputcsv=os.path.join(user["osmfolder"],"tmp_bash2.sh")
f = open(outputcsv, 'w')
f.write(cmdline)
f.close()

# %%
from subprocess import Popen, PIPE, STDOUT
p = Popen(['osm2pgsql','-c','-d',user["dbname"],'-W','-U',user["user"],
           '-H',user["host"],'--extra-attributes','-p',user["prefixosm"],
           '-S',user["stylefile"],os.path.join(user["osmfolder"],user["prefixosm"]+".osm")], 
          stdout=PIPE, stdin=PIPE, stderr=STDOUT)    
bash_stdout = p.communicate(input=user["password"])[0]
print(bash_stdout.decode())
# Out:
# osm2pgsql version 0.94.0 (64 bit id space)
#
# Password:
# Using built-in tag processing pipeline
# Using projection SRS 3857 (Spherical Mercator)
# Setting up table: osm_point
# Setting up table: osm_line
# Setting up table: osm_polygon
# Setting up table: osm_roads
# Allocating memory for dense node cache
# Allocating dense node cache in one big chunk
# Allocating memory for sparse node cache
# Sharing dense sparse
# Node-cache: cache=800MB, maxblocks=12800*65536, allocation method=3
#
# Reading in file: /Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/Mapathon2018_belgiumuni/osm.osm
# Using XML parser.
# Processing: Node(596k 33.1k/s) Way(60k 20.00k/s) Relation(0 0.00/s)  parse time: 22s
# Node stats: total(596474), max(5518117022) in 18s
# Way stats: total(79716), max(574981809) in 3s
# Relation stats: total(31), max(8142583) in 0s
# Committing transaction for osm_point
# Committing transaction for osm_line
# Committing transaction for osm_polygon
# Committing transaction for osm_roads
# Using built-in tag processing pipeline
# Using built-in tag processing pipeline
# Using built-in tag processing pipeline
# Using built-in tag processing pipeline
#
# Going over pending ways...
# 	77604 ways are pending
#
# Using 4 helper-processes
# Finished processing 77604 ways in 2 s
#
# 77604 Pending ways took 2s at a rate of 38802.00/s
# Committing transaction for osm_point
# Committing transaction for osm_line
# Committing transaction for osm_polygon
# Committing transaction for osm_roads
# Committing transaction for osm_point
# Committing transaction for osm_line
# Committing transaction for osm_polygon
# Committing transaction for osm_roads
# Committing transaction for osm_point
# Committing transaction for osm_line
# Committing transaction for osm_polygon
# Committing transaction for osm_roads
# Committing transaction for osm_point
# Committing transaction for osm_line
# Committing transaction for osm_polygon
# Committing transaction for osm_roads
#
# Going over pending relations...
# 	0 relations are pending
#
# Using 4 helper-processes
# Finished processing 0 relations in 0 s
#
# Committing transaction for osm_point
# WARNING:  there is no transaction in progress
# Committing transaction for osm_line
# WARNING:  there is no transaction in progress
# Committing transaction for osm_polygon
# WARNING:  there is no transaction in progress
# Committing transaction for osm_roads
# WARNING:  there is no transaction in progress
# Committing transaction for osm_point
# WARNING:  there is no transaction in progress
# Committing transaction for osm_line
# WARNING:  there is no transaction in progress
# Committing transaction for osm_polygon
# WARNING:  there is no transaction in progress
# Committing transaction for osm_roads
# WARNING:  there is no transaction in progress
# Committing transaction for osm_point
# WARNING:  there is no transaction in progress
# Committing transaction for osm_line
# WARNING:  there is no transaction in progress
# Committing transaction for osm_polygon
# WARNING:  there is no transaction in progress
# Committing transaction for osm_roads
# WARNING:  there is no transaction in progress
# Committing transaction for osm_point
# WARNING:  there is no transaction in progress
# Committing transaction for osm_line
# WARNING:  there is no transaction in progress
# Committing transaction for osm_polygon
# WARNING:  there is no transaction in progress
# Committing transaction for osm_roads
# WARNING:  there is no transaction in progress
# Sorting data and creating indexes for osm_point
# node cache: stored: 596474(100.00%), storage efficiency: 57.04% (dense blocks: 58, sparse nodes: 285268), hit rate: 99.89%
# Sorting data and creating indexes for osm_line
# Sorting data and creating indexes for osm_polygon
# Sorting data and creating indexes for osm_roads
# Copying osm_roads to cluster by geometry finished
# Creating geometry index on osm_roads
# Creating indexes on osm_roads finished
# All indexes on osm_roads created in 0s
# Completed osm_roads
# Copying osm_point to cluster by geometry finished
# Creating geometry index on osm_point
# Copying osm_line to cluster by geometry finished
# Creating geometry index on osm_line
# Creating indexes on osm_line finished
# All indexes on osm_line created in 0s
# Completed osm_line
# Creating indexes on osm_point finished
# All indexes on osm_point created in 0s
# Completed osm_point
# Copying osm_polygon to cluster by geometry finished
# Creating geometry index on osm_polygon
# Creating indexes on osm_polygon finished
# All indexes on osm_polygon created in 23s
# Completed osm_polygon
#
# Osm2pgsql took 48s overall

# %%
## Erase the temporary 'reclass_rule.csv' file
os.remove(outputcsv)

# %% [markdown]
# Here after, the osm table "line" and "polygon" will be moved to the current user's schema.
#
# As HOT's tasks (Humanitarian OpenStreetMap Team) generally focus on highways, buildings and residential area, these features are the only one kept for the rest of this notebook. If you need something else, you should adapt the code.

# %%
## Move tables "lines" and "polygons" in current schema

# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS "+user["schema"]+"."+user["prefixosm"]+"_"+"line")
# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon")
# Make the changes to the database persistent
db.commit()

# Copy table from public schema to current schema (only intersections with AOI):
subquery1="WITH \
lines AS(\
SELECT  (ST_Dump(ST_Intersection(ST_Transform(l.way,4326), ST_Transform(aoi.geom,4326)))).geom AS the_geom, l.*  \
FROM "+user["schema"]+"."+user["aoi"]+" AS aoi, public."+user["prefixosm"]+"_"+"line"+" AS l \
WHERE l.highway is not null) \
\
SELECT * FROM lines"
# Query
query="CREATE TABLE "+user["schema"]+"."+user["prefixosm"]+"_"+"line AS ("
query+=subquery1+")"
# Execute the CREATE TABLE query 
cur.execute(query)

# Copy table from public schema to current schema (only intersections with AOI):
subquery1="WITH \
poly AS(\
SELECT  (ST_Dump(ST_Intersection(ST_Transform(p.way,4326), ST_Transform(aoi.geom,4326)))).geom AS the_geom, p.*  \
FROM "+user["schema"]+"."+user["aoi"]+" AS aoi, public."+user["prefixosm"]+"_"+"polygon"+" AS p \
WHERE  p.building is not NULL OR p.landuse = 'residential' ) \
\
SELECT * FROM poly"
# Query
query="CREATE TABLE "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon AS ("
query+=subquery1+")"
# Execute the CREATE TABLE query 
cur.execute(query)
# Make the changes to the database persistent
db.commit()

# Drop 'way' column if exists:
cur.execute("ALTER TABLE "+user["schema"]+"."+user["prefixosm"]+"_"+"line DROP COLUMN IF EXISTS way")
# Drop table if exists:
cur.execute("ALTER TABLE "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon DROP COLUMN IF EXISTS way")
# Make the changes to the database persistent
db.commit()

# %% [markdown]
# Here after, the table in the "public" schema will be droped.

# %%
## Drop tables of public schema which will not be used anymore

# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS public."+user["prefixosm"]+"_"+"point")
# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS public."+user["prefixosm"]+"_"+"roads")
# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS public."+user["prefixosm"]+"_"+"line")
# Drop table if exists:
cur.execute("DROP TABLE IF EXISTS public."+user["prefixosm"]+"_"+"polygon")

# Make the changes to the database persistent
db.commit()

# %% [markdown]
# **-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-**

# %% [markdown]
# # Timestamp for Qgis timemanager plugin

# %% [markdown]
# ## Add new colum 'forever' for Qgis timemanager

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# Query:
cur.execute("ALTER TABLE "+user["schema"]+"."+user["prefixosm"]+"_"+"line ADD COLUMN IF NOT EXISTS forever timestamp(0) with time zone")
cur.execute("ALTER TABLE "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon ADD COLUMN IF NOT EXISTS forever timestamp(0) with time zone")

# Make the changes to the database persistent
db.commit()

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Open a cursor to perform database operations
cur=db.cursor()

# Query:
cur.execute("UPDATE "+user["schema"]+"."+user["prefixosm"]+"_"+"line SET forever=TIMESTAMP WITH TIME ZONE '2030-01-01 00:00:00+01'")
cur.execute("UPDATE "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon SET forever=TIMESTAMP WITH TIME ZONE '2030-01-01 00:00:00+01'")
# Make the changes to the database persistent
db.commit()

# %% [markdown]
# # Export shapefile

# %% [markdown]
# Here after, the tables 'line' and 'polygon' are exported from Postgis as shapefiles for gentle use in Qgis.

# %% [markdown]
# ### Export lines table

# %%
from subprocess import Popen, PIPE, STDOUT
p = Popen(['pgsql2shp','-f',user["output_lineshp"],
           "-h",user["host"],"-u",user["user"],"-P",user["password"],
           user["dbname"],user["schema"]+"."+user["prefixosm"]+"_"+"line"], 
          stdout=PIPE, stdin=PIPE, stderr=STDOUT)    
bash_stdout = p.communicate(input=user["password"])[0]
print(bash_stdout.decode())
# Out:
# Initializing...
# Done (postgis major version: 2).
# Output shape: PolyLine
# Dumping: XXXXXXXXXXXXXXXXXXXXX [2056 rows].

# %% [markdown]
# ### Export polygons table

# %%
from subprocess import Popen, PIPE, STDOUT
p = Popen(['pgsql2shp','-f',user["output_polygonshp"],
           "-h",user["host"],"-u",user["user"],"-P",user["password"],
           user["dbname"],user["schema"]+"."+user["prefixosm"]+"_"+"polygon"], 
          stdout=PIPE, stdin=PIPE, stderr=STDOUT)    
bash_stdout = p.communicate(input=user["password"])[0]
print(bash_stdout.decode())
# Out:
# Initializing...
# Done (postgis major version: 2).
# Output shape: Polygon
# Dumping: ... [74317 rows].

# %% [markdown]
# # Mapathon statistics

# %% [markdown]
# Here after, some basic stats are computed to inform on key infos of the mapathon. You could add extra stats if you want.

# %%
# Enter starting time of the mapathon (YYYY-MM-DD HH:MM:SS)
begintimemapping='2018-03-24 08:00:00'
# Enter ending time of the mapathon (YYYY-MM-DD HH:MM:SS)
endingtimemapping='2018-03-24 18:00:00'

# %% [markdown]
# ### Number of unique mapper

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="WITH distinctuser_line AS(\
SELECT DISTINCT osm_user FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"line \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"'), \
\
distinctuser_polygon AS(\
SELECT DISTINCT osm_user FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"'), \
\
global_distinctuser AS(\
SELECT * FROM distinctuser_line \
UNION \
SELECT * FROM distinctuser_polygon)\
\
SELECT count(*) FROM global_distinctuser"

# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#    count
# 0    263

# %% [markdown]
# ### Number of editions by mapper

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="WITH \
all_edits AS(\
SELECT * FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"line \
UNION \
SELECT * FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon) \
\
SELECT osm_user, count(*) AS count FROM all_edits \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
GROUP BY osm_user \
ORDER BY count(*) DESC"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#                 osm_user  count
# 0               Céline94   1195
# 1                  leril   1170
# 2             ArticCynda   1118
# 3                 fpriem   1047
# 4               evdegaer    900
# 5        Klara Dvorakova    862
# 6   Thomas Vandecappelle    844
# 7              smossoux2    800
# 8                Freez09    796
# 9                 WendyR    782
# 10      Georgery Florent    742
# 11          JulietteROME    738
# 12               Chrilou    718
# 13              lolo2472    707
# 14             savleesch    704
# 15             Vanille07    699
# 16  Barthélémy Haincourt    688
# 17            Geogmapper    667
# 18                jj_geo    666
# 19             Meryem El    642
# 20           Notanumber8    642
# 21         Tim Couwelier    628
# 22            Guillaume3    618
# 23             Pauline17    594
# 24            Steven1555    590
# 25               Nervang    586
# 26                JShrek    577
# 27             HildeVerb    566
# 28         François Rigo    562
# 29            Lucas Wpch    561
# 30               Jules19    560
# 31                 Ubipo    548
# 32                Emy170    545
# 33             RobertBau    537
# 34      Massimo Camastra    535
# 35               AlizéeS    534
# 36        manon muratore    531
# 37          Rahimi Samim    521
# 38                 Rulus    518
# 39           JustineEloy    516
# 40            pauline500    491
# 41               Anne DW    484
# 42         aline legrand    477
# 43              MrFrazil    476
# 44            broussieau    465
# 45                 cstal    463
# 46                jobzzi    463
# 47                 eli2s    455
# 48              ccloquet    446
# 49            Florence L    445

# %%
listuser=df_bbox_coord['osm_user']
listcount=df_bbox_coord['count']
mardowntable=[]
mardowntable.append("rank|user|edits")
mardowntable.append("--- | --- | ---")
[mardowntable.append("%s|%s|%s"%(i,a[0],a[1])) for i,a in enumerate(zip(listuser,listcount),1)]
print "\n".join(mardowntable)
# Out:
# rank|user|edits
# --- | --- | ---
# 1|Céline94|1195
# 2|leril|1170
# 3|ArticCynda|1118
# 4|fpriem|1047
# 5|evdegaer|900
# 6|Klara Dvorakova|862
# 7|Thomas Vandecappelle|844
# 8|smossoux2|800
# 9|Freez09|796
# 10|WendyR|782
# 11|Georgery Florent|742
# 12|JulietteROME|738
# 13|Chrilou|718
# 14|lolo2472|707
# 15|savleesch|704
# 16|Vanille07|699
# 17|Barthélémy Haincourt|688
# 18|Geogmapper|667
# 19|jj_geo|666
# 20|Meryem El|642
# 21|Notanumber8|642
# 22|Tim Couwelier|628
# 23|Guillaume3|618
# 24|Pauline17|594
# 25|Steven1555|590
# 26|Nervang|586
# 27|JShrek|577
# 28|HildeVerb|566
# 29|François Rigo|562
# 30|Lucas Wpch|561
# 31|Jules19|560
# 32|Ubipo|548
# 33|Emy170|545
# 34|RobertBau|537
# 35|Massimo Camastra|535
# 36|AlizéeS|534
# 37|manon muratore|531
# 38|Rahimi Samim|521
# 39|Rulus|518
# 40|JustineEloy|516
# 41|pauline500|491
# 42|Anne DW|484
# 43|aline legrand|477
# 44|MrFrazil|476
# 45|broussieau|465
# 46|cstal|463
# 47|jobzzi|463
# 48|eli2s|455
# 49|ccloquet|446
# 50|Florence L|445
# 51|TristanSatinet|437
# 52|Daamiien|430
# 53|GertVanhollebeke|430
# 54|Mathieud3|426
# 55|Slvn01|419
# 56|Justine Cloquette|417
# 57|StephanieMarlot|411
# 58|Clem2710|411
# 59|GaetanP|394
# 60|Anouk Cauwels|394
# 61|skjhfdgls|392
# 62|Noémie Denayer|381
# 63|AmélieP|381
# 64|IreB-S|377
# 65|Florian wu|370
# 66|Joke Dewaele|364
# 67|Céline Descamps|362
# 68|thomas_huin|362
# 69|Buyse|359
# 70|Vucodil|359
# 71|LN22|358
# 72|Timon Deputter|357
# 73|Jerem_K|356
# 74|Potato_Spirit|356
# 75|Jolijn De Cordier|356
# 76|MikeDilien|355
# 77|VickyDH|353
# 78|JM_Jacq|350
# 79|michiel maertens|346
# 80|melBOSM|342
# 81|Elane M|338
# 82|anouk_h|335
# 83|alfers|334
# 84|gaetandujardin|334
# 85|wouterp|332
# 86|Djeunz|327
# 87|PierreVer|327
# 88|Mapathon18|325
# 89|MassimoBennardo|324
# 90|QGlaude|324
# 91|ManD1408|320
# 92|laurentthomas|319
# 93|dorienvdh|317
# 94|Muriel Hiernaux|316
# 95|wellensw|315
# 96|rdevooght|303
# 97|Marcos067|298
# 98|Pascaline Wallemacq|297
# 99|Planchet|293
# 100|Marie Sk|292
# 101|Patcach-be|292
# 102|Celena S|291
# 103|lieson|284
# 104|chiem1|283
# 105|alitrgx|283
# 106|tmarchan|276
# 107|Jan Anthonissen|271
# 108|DVercamer|269
# 109|jeroen25|268
# 110|Maxence176|266
# 111|Quentin Brouette|263
# 112|matterYflow|260
# 113|alicevm|259
# 114|kevin quesne|258
# 115|Benjamosm|255
# 116|emcastin|252
# 117|Alexandre Gillieaux|252
# 118|BobFery|249
# 119|Elwymo|248
# 120|jochen22|247
# 121|JanHoremans|242
# 122|eliselaure|242
# 123|Eirini Skr|241
# 124|EliH1|240
# 125|ChloéYamina|239
# 126|LukaBen|238
# 127|stanvdm|237
# 128|JaninaClark|235
# 129|Delaiglematteo|234
# 130|DeprêtreA|228
# 131|Nathalie C|227
# 132|alvilech|222
# 133|Tania Wolski|222
# 134|Francoise Skirole|221
# 135|FBaltha|217
# 136|Frwal|214
# 137|Eric Georis|213
# 138|lidruytt|213
# 139|Sabine Soetewey|211
# 140|BrieucvC|210
# 141|chlhayon|209
# 142|LaurentMB|208
# 143|Sapho Warin|202
# 144|KoalaAnn|202
# 145|Cathyp|199
# 146|TimTherry|197
# 147|Véronique DEHON|197
# 148|priscillafligitter|196
# 149|Wouter8|195
# 150|Agnès Wilkanowski|194
# 151|Jorieke V|194
# 152|TG22|194
# 153|danvid_d|193
# 154|De Berraly anne|191
# 155|Ceeblim|185
# 156|SAY87J|185
# 157|camille lerquet|181
# 158|JFDel|180
# 159|Macaux|179
# 160|WatsonF|178
# 161|Binetabah|178
# 162|khadmi|175
# 163|Eleuthere|173
# 164|Pascalou1000|173
# 165|Sara Brancart|172
# 166|Pieter Vander Vennet|169
# 167|Zappi211|169
# 168|ouaip123|167
# 169|Marie Decruyenaere|167
# 170|pabpab|165
# 171|BjarneCol|163
# 172|Charlie F|163
# 173|kcockx|163
# 174|Laetitia Roos|160
# 175|mclaeysb|159
# 176|michele_jergeay|158
# 177|mledent|155
# 178|JPL|155
# 179|bdht|149
# 180|JusteChloé|146
# 181|Matthieu Kervyn|142
# 182|Pieter Temmerman|141
# 183|bavos|139
# 184|Enyo Vanmontfort|139
# 185|ludivinelavaert|139
# 186|valthebestIII|139
# 187|Stani2018|136
# 188|SLadouce|136
# 189|Eléonore Wolff|134
# 190|mcorcora|133
# 191|Caroline Canon|132
# 192|linusable|131
# 193|HOUNKPE Joseph|131
# 194|FrankCantersVUB3|129
# 195|caroline bossaert|127
# 196|Sabine M|127
# 197|VictorPreaux|121
# 198|nxwbcnbvx|113
# 199|ClaireMrt|108
# 200|Loïs Magain|105
# 201|JBihin|103
# 202|stellad|103
# 203|Corentin Sanchez|97
# 204|josusm|96
# 205|Quentin Jans|96
# 206|Enila|95
# 207|Coralie Rottier|94
# 208|Madeleine Guyot|93
# 209|Mapathon01|92
# 210|phy|91
# 211|Jérôme Collin|88
# 212|Jakka|88
# 213|DelphineBelgium|87
# 214|isaurerenaville|85
# 215|Brigitte Ancion|83
# 216|Annick Anceau|82
# 217|MarieDmb|82
# 218|Alda Sela|81
# 219|Bernard@axsmb|80
# 220|olavzk|79
# 221|cyclo1860|79
# 222|Clotilde|78
# 223|Marcovaldo|78
# 224|clinard|77
# 225|lacaracole|76
# 226|Bé Piroton|73
# 227|Mapathon02|71
# 228|Bosco_Bwambale|70
# 229|jeverbeu|69
# 230|Emilie w|69
# 231|soyer j|68
# 232|oborsus|68
# 233|vello4|67
# 234|Egentz Joseph|60
# 235|SLe9|58
# 236|Gossebeaudu11|58
# 237|Phutphalla|54
# 238|lenerock|49
# 239|M-C Binard|46
# 240|Anton44|44
# 241|julie st jac|42
# 242|ChVt|38
# 243|elke1980|38
# 244|Georges Duculot|27
# 245|Pierre Cornut|26
# 246|Hugo Périlleux Sanchez|26
# 247|KristienOoms|26
# 248|KriziaT|21
# 249|Nic_17|21
# 250|QADDOURI|21
# 251|jbelien|19
# 252|Oliverhertsens|19
# 253|maanblau|18
# 254|SilvanaVF|18
# 255|joost schouppe|17
# 256|Michel SCHOLTES|16
# 257|Celkooo|16
# 258|Mapathon Rhétos|15
# 259|Olivier Delarte|14
# 260|Steaven|12
# 261|mpapy|11
# 262|NOTREDAME|4
# 263|Patrick_1962|3

# %% [markdown]
# ### Number of buildings mapped

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="SELECT count(*) FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND building is not null"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#    count
# 0  70970

# %% [markdown]
# ### Number of Buildings by mapper

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="\
SELECT osm_user, count(*) AS count FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND building IS NOT NULL \
GROUP BY osm_user \
ORDER BY count(*) DESC"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#                 osm_user  count
# 0               Céline94   1190
# 1                  leril   1148
# 2             ArticCynda   1048
# 3                 fpriem   1033
# 4               evdegaer    899
# 5        Klara Dvorakova    853
# 6   Thomas Vandecappelle    838
# 7              smossoux2    792
# 8                Freez09    772
# 9                 WendyR    767
# 10      Georgery Florent    730
# 11          JulietteROME    717
# 12               Chrilou    710
# 13             savleesch    704
# 14              lolo2472    684
# 15  Barthélémy Haincourt    680
# 16             Vanille07    678
# 17            Geogmapper    663
# 18             Meryem El    642
# 19           Notanumber8    633
# 20         Tim Couwelier    628
# 21                jj_geo    622
# 22            Guillaume3    617
# 23             Pauline17    577
# 24                JShrek    575
# 25            Steven1555    573
# 26             HildeVerb    563
# 27                Emy170    534
# 28               Nervang    533
# 29               Jules19    532
# 30               AlizéeS    525
# 31        manon muratore    522
# 32          Rahimi Samim    517
# 33                 Rulus    515
# 34      Massimo Camastra    508
# 35             RobertBau    503
# 36         François Rigo    501
# 37            Lucas Wpch    489
# 38           JustineEloy    488
# 39               Anne DW    479
# 40            pauline500    476
# 41         aline legrand    475
# 42              MrFrazil    468
# 43            broussieau    465
# 44                 Ubipo    462
# 45                 eli2s    445
# 46              ccloquet    441
# 47        TristanSatinet    429
# 48                jobzzi    428
# 49      GertVanhollebeke    427

# %%
listuser=df_bbox_coord['osm_user']
listcount=df_bbox_coord['count']
mardowntable=[]
mardowntable.append("rank|user|buildings")
mardowntable.append("--- | --- | ---")
[mardowntable.append("%s|%s|%s"%(i,a[0],a[1])) for i,a in enumerate(zip(listuser,listcount),1)]
print "\n".join(mardowntable)
# Out:
# rank|user|buildings
# --- | --- | ---
# 1|Céline94|1190
# 2|leril|1148
# 3|ArticCynda|1048
# 4|fpriem|1033
# 5|evdegaer|899
# 6|Klara Dvorakova|853
# 7|Thomas Vandecappelle|838
# 8|smossoux2|792
# 9|Freez09|772
# 10|WendyR|767
# 11|Georgery Florent|730
# 12|JulietteROME|717
# 13|Chrilou|710
# 14|savleesch|704
# 15|lolo2472|684
# 16|Barthélémy Haincourt|680
# 17|Vanille07|678
# 18|Geogmapper|663
# 19|Meryem El|642
# 20|Notanumber8|633
# 21|Tim Couwelier|628
# 22|jj_geo|622
# 23|Guillaume3|617
# 24|Pauline17|577
# 25|JShrek|575
# 26|Steven1555|573
# 27|HildeVerb|563
# 28|Emy170|534
# 29|Nervang|533
# 30|Jules19|532
# 31|AlizéeS|525
# 32|manon muratore|522
# 33|Rahimi Samim|517
# 34|Rulus|515
# 35|Massimo Camastra|508
# 36|RobertBau|503
# 37|François Rigo|501
# 38|Lucas Wpch|489
# 39|JustineEloy|488
# 40|Anne DW|479
# 41|pauline500|476
# 42|aline legrand|475
# 43|MrFrazil|468
# 44|broussieau|465
# 45|Ubipo|462
# 46|eli2s|445
# 47|ccloquet|441
# 48|TristanSatinet|429
# 49|jobzzi|428
# 50|GertVanhollebeke|427
# 51|Florence L|427
# 52|Mathieud3|419
# 53|Slvn01|417
# 54|Justine Cloquette|417
# 55|Clem2710|408
# 56|Daamiien|404
# 57|GaetanP|394
# 58|StephanieMarlot|392
# 59|skjhfdgls|379
# 60|Anouk Cauwels|378
# 61|IreB-S|377
# 62|cstal|375
# 63|Noémie Denayer|374
# 64|Joke Dewaele|364
# 65|thomas_huin|359
# 66|Vucodil|357
# 67|AmélieP|356
# 68|Jolijn De Cordier|356
# 69|Céline Descamps|356
# 70|Jerem_K|355
# 71|Florian wu|354
# 72|VickyDH|353
# 73|Buyse|349
# 74|JM_Jacq|348
# 75|LN22|347
# 76|MikeDilien|345
# 77|melBOSM|339
# 78|Potato_Spirit|338
# 79|michiel maertens|338
# 80|anouk_h|335
# 81|wouterp|332
# 82|alfers|330
# 83|Elane M|328
# 84|gaetandujardin|327
# 85|Mapathon18|325
# 86|Timon Deputter|322
# 87|QGlaude|322
# 88|ManD1408|320
# 89|PierreVer|318
# 90|wellensw|311
# 91|laurentthomas|306
# 92|Muriel Hiernaux|306
# 93|Djeunz|305
# 94|MassimoBennardo|299
# 95|Marcos067|298
# 96|dorienvdh|295
# 97|Pascaline Wallemacq|293
# 98|rdevooght|292
# 99|Celena S|291
# 100|Planchet|288
# 101|Marie Sk|288
# 102|chiem1|283
# 103|lieson|283
# 104|tmarchan|276
# 105|alitrgx|273
# 106|jeroen25|268
# 107|Jan Anthonissen|265
# 108|Maxence176|262
# 109|Quentin Brouette|262
# 110|alicevm|259
# 111|DVercamer|257
# 112|matterYflow|257
# 113|kevin quesne|250
# 114|emcastin|250
# 115|Benjamosm|250
# 116|BobFery|246
# 117|Alexandre Gillieaux|244
# 118|Eirini Skr|241
# 119|EliH1|240
# 120|jochen22|238
# 121|stanvdm|237
# 122|Delaiglematteo|234
# 123|LukaBen|230
# 124|DeprêtreA|228
# 125|JaninaClark|222
# 126|Elwymo|222
# 127|JanHoremans|220
# 128|ChloéYamina|219
# 129|Tania Wolski|218
# 130|Nathalie C|216
# 131|Frwal|214
# 132|Eric Georis|213
# 133|Francoise Skirole|213
# 134|FBaltha|212
# 135|alvilech|211
# 136|BrieucvC|210
# 137|eliselaure|209
# 138|chlhayon|208
# 139|LaurentMB|206
# 140|Sabine Soetewey|206
# 141|lidruytt|205
# 142|KoalaAnn|198
# 143|Cathyp|197
# 144|Sapho Warin|195
# 145|Wouter8|194
# 146|Agnès Wilkanowski|194
# 147|priscillafligitter|194
# 148|danvid_d|193
# 149|Véronique DEHON|190
# 150|De Berraly anne|188
# 151|TimTherry|187
# 152|SAY87J|185
# 153|Ceeblim|184
# 154|camille lerquet|181
# 155|WatsonF|178
# 156|JFDel|177
# 157|Macaux|177
# 158|Pascalou1000|173
# 159|Marie Decruyenaere|167
# 160|Sara Brancart|166
# 161|ouaip123|166
# 162|Patcach-be|165
# 163|Eleuthere|163
# 164|BjarneCol|163
# 165|kcockx|161
# 166|mclaeysb|158
# 167|michele_jergeay|158
# 168|Binetabah|158
# 169|khadmi|157
# 170|pabpab|156
# 171|Charlie F|156
# 172|Zappi211|155
# 173|mledent|155
# 174|Jorieke V|153
# 175|TG22|152
# 176|JPL|151
# 177|Laetitia Roos|150
# 178|bdht|149
# 179|JusteChloé|146
# 180|Pieter Temmerman|141
# 181|Matthieu Kervyn|140
# 182|bavos|139
# 183|Enyo Vanmontfort|139
# 184|ludivinelavaert|138
# 185|Caroline Canon|132
# 186|linusable|130
# 187|Sabine M|127
# 188|Eléonore Wolff|127
# 189|caroline bossaert|127
# 190|FrankCantersVUB3|123
# 191|valthebestIII|122
# 192|mcorcora|122
# 193|Stani2018|119
# 194|VictorPreaux|115
# 195|SLadouce|115
# 196|nxwbcnbvx|112
# 197|ClaireMrt|107
# 198|HOUNKPE Joseph|105
# 199|stellad|103
# 200|JBihin|103
# 201|Loïs Magain|98
# 202|Corentin Sanchez|96
# 203|josusm|96
# 204|Enila|95
# 205|Quentin Jans|92
# 206|Mapathon01|92
# 207|Pieter Vander Vennet|89
# 208|Jérôme Collin|88
# 209|DelphineBelgium|87
# 210|Jakka|86
# 211|isaurerenaville|85
# 212|Madeleine Guyot|84
# 213|Brigitte Ancion|83
# 214|Coralie Rottier|81
# 215|Alda Sela|80
# 216|Bernard@axsmb|80
# 217|Annick Anceau|80
# 218|olavzk|79
# 219|Clotilde|78
# 220|cyclo1860|78
# 221|Marcovaldo|77
# 222|clinard|77
# 223|lacaracole|76
# 224|MarieDmb|72
# 225|Bé Piroton|69
# 226|jeverbeu|69
# 227|phy|67
# 228|Mapathon02|66
# 229|oborsus|65
# 230|Emilie w|64
# 231|vello4|63
# 232|soyer j|61
# 233|Egentz Joseph|60
# 234|Gossebeaudu11|57
# 235|SLe9|55
# 236|lenerock|49
# 237|M-C Binard|46
# 238|Anton44|44
# 239|julie st jac|40
# 240|ChVt|38
# 241|elke1980|38
# 242|Phutphalla|31
# 243|KristienOoms|26
# 244|Pierre Cornut|24
# 245|Hugo Périlleux Sanchez|23
# 246|Nic_17|21
# 247|Georges Duculot|20
# 248|KriziaT|20
# 249|QADDOURI|18
# 250|Oliverhertsens|17
# 251|maanblau|17
# 252|Michel SCHOLTES|16
# 253|Celkooo|16
# 254|SilvanaVF|14
# 255|Olivier Delarte|14
# 256|jbelien|13
# 257|joost schouppe|12
# 258|Bosco_Bwambale|12
# 259|Steaven|12
# 260|mpapy|11
# 261|Mapathon Rhétos|9
# 262|NOTREDAME|4
# 263|Patrick_1962|3

# %% [markdown]
# ### Number of residential area mapped

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="SELECT count(*) FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND landuse='residential'"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#    count
# 0   1263

# %% [markdown]
# ### Cumulated area of residential area mapped

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="SELECT sum(ST_Area(ST_Transform(the_geom,"+ESPG_UTM+")))/1000000 AS km2_residential FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"polygon \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND landuse='residential'"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#    km2_residential
# 0        29.744125

# %% [markdown]
# ### Number of roads mapped

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="SELECT count(*) FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"line \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND highway is not null"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#    count
# 0   1148

# %% [markdown]
# ### Cumulated distance of roads mapped

# %%
ESPG_UTM="32632"

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="SELECT sum(ST_Length(ST_Transform(the_geom,"+ESPG_UTM+")))/1000 AS km_road FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"line \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND highway is not null"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#       km_road
# 0  277.371382

# %% [markdown]
# ### Cumulated distance of road by mapper

# %%
# Connect to an existing database
db=pg.connect(dbname=user["dbname"], user=user["user"], password=user["password"], host=user["host"])
# Number of line to show (please limit to 100 for saving computing time)
nbrow=500
# Query
query="\
SELECT osm_user, sum(ST_Length(ST_Transform(the_geom,"+ESPG_UTM+")))/1000 AS km_road FROM "+user["schema"]+"."+user["prefixosm"]+"_"+"line \
WHERE osm_timestamp >= '"+str(begintimemapping)+"' AND osm_timestamp <= '"+str(endingtimemapping)+"' \
AND highway IS NOT NULL \
GROUP BY osm_user \
ORDER BY km_road DESC"
# Execute query through panda
df_bbox_coord=pd.read_sql(query, db)
# Show dataframe
df_bbox_coord.head(50)
# Out:
#                 osm_user    km_road
# 0   Pieter Vander Vennet  26.780207
# 1         Bosco_Bwambale  17.843073
# 2                  Ubipo  16.499218
# 3             Patcach-be  14.711452
# 4                    phy  13.529825
# 5                  cstal  13.249746
# 6               SLadouce  11.822905
# 7                AmélieP  10.593650
# 8               lolo2472  10.013440
# 9             Lucas Wpch   8.765242
# 10         François Rigo   7.857084
# 11            ArticCynda   7.491318
# 12                jj_geo   7.211075
# 13             Jorieke V   6.172996
# 14             RobertBau   6.053983
# 15               Nervang   5.794347
# 16                jobzzi   4.877696
# 17                  TG22   4.845281
# 18         Anouk Cauwels   4.743597
# 19        Timon Deputter   4.079504
# 20           ChloéYamina   3.906607
# 21                Elwymo   3.812749
# 22      michiel maertens   3.628646
# 23                khadmi   3.476557
# 24             Stani2018   3.259534
# 25           JaninaClark   2.378135
# 26               AlizéeS   2.310449
# 27              Emilie w   2.283594
# 28       Madeleine Guyot   2.159628
# 29            Geogmapper   2.069453
# 30                Emy170   1.978401
# 31         valthebestIII   1.945691
# 32             DVercamer   1.778484
# 33        HOUNKPE Joseph   1.714028
# 34             Eleuthere   1.683602
# 35      Massimo Camastra   1.587355
# 36            Florence L   1.546712
# 37        Eléonore Wolff   1.503747
# 38      Georgery Florent   1.441028
# 39        joost schouppe   1.405829
# 40     Francoise Skirole   1.179008
# 41               jbelien   1.178992
# 42              Zappi211   1.166776
# 43         laurentthomas   1.161573
# 44                   JPL   1.151773
# 45       Georges Duculot   1.144405
# 46             Vanille07   1.142755
# 47             TimTherry   1.091765
# 48           Loïs Magain   1.052262
# 49         Sara Brancart   0.942493

# %%
listuser=df_bbox_coord['osm_user']
listcount=df_bbox_coord['km_road']
mardowntable=[]
mardowntable.append("rank|user|km_road")
mardowntable.append("--- | --- | ---")
[mardowntable.append("%s|%s|%s"%(i,a[0],round(a[1],2))) for i,a in enumerate(zip(listuser,listcount),1)]
print "\n".join(mardowntable)
# Out:
# rank|user|km_road
# --- | --- | ---
# 1|Pieter Vander Vennet|26.78
# 2|Bosco_Bwambale|17.84
# 3|Ubipo|16.5
# 4|Patcach-be|14.71
# 5|phy|13.53
# 6|cstal|13.25
# 7|SLadouce|11.82
# 8|AmélieP|10.59
# 9|lolo2472|10.01
# 10|Lucas Wpch|8.77
# 11|François Rigo|7.86
# 12|ArticCynda|7.49
# 13|jj_geo|7.21
# 14|Jorieke V|6.17
# 15|RobertBau|6.05
# 16|Nervang|5.79
# 17|jobzzi|4.88
# 18|TG22|4.85
# 19|Anouk Cauwels|4.74
# 20|Timon Deputter|4.08
# 21|ChloéYamina|3.91
# 22|Elwymo|3.81
# 23|michiel maertens|3.63
# 24|khadmi|3.48
# 25|Stani2018|3.26
# 26|JaninaClark|2.38
# 27|AlizéeS|2.31
# 28|Emilie w|2.28
# 29|Madeleine Guyot|2.16
# 30|Geogmapper|2.07
# 31|Emy170|1.98
# 32|valthebestIII|1.95
# 33|DVercamer|1.78
# 34|HOUNKPE Joseph|1.71
# 35|Eleuthere|1.68
# 36|Massimo Camastra|1.59
# 37|Florence L|1.55
# 38|Eléonore Wolff|1.5
# 39|Georgery Florent|1.44
# 40|joost schouppe|1.41
# 41|Francoise Skirole|1.18
# 42|jbelien|1.18
# 43|Zappi211|1.17
# 44|laurentthomas|1.16
# 45|JPL|1.15
# 46|Georges Duculot|1.14
# 47|Vanille07|1.14
# 48|TimTherry|1.09
# 49|Loïs Magain|1.05
# 50|Sara Brancart|0.94
# 51|De Berraly anne|0.93
# 52|Barthélémy Haincourt|0.87
# 53|wellensw|0.85
# 54|Sapho Warin|0.84
# 55|Mapathon02|0.83
# 56|Mapathon Rhétos|0.81
# 57|Céline94|0.81
# 58|Cathyp|0.75
# 59|SLe9|0.73
# 60|LN22|0.66
# 61|Freez09|0.66
# 62|JustineEloy|0.66
# 63|Rahimi Samim|0.62
# 64|Phutphalla|0.61
# 65|SilvanaVF|0.6
# 66|fpriem|0.54
# 67|leril|0.49
# 68|MarieDmb|0.47
# 69|vello4|0.45
# 70|QADDOURI|0.43
# 71|Oliverhertsens|0.41
# 72|Klara Dvorakova|0.38
# 73|matterYflow|0.36
# 74|lieson|0.36
# 75|MassimoBennardo|0.35
# 76|alfers|0.35
# 77|pauline500|0.33
# 78|HildeVerb|0.28
# 79|Nathalie C|0.25
# 80|Jerem_K|0.19
# 81|Quentin Jans|0.16
# 82|Macaux|0.14
# 83|ouaip123|0.12
# 84|Bé Piroton|0.06

# %% [markdown]
# # Create map frames using Time Manager Plugin

# %% [markdown]
# **This step should be done outsite from this notebook.**
#
# Use the [Qgis time manager plugin](https://github.com/anitagraser/TimeManager) to produced maps frames. More info could be found on the [Anita Graser's blog](https://anitagraser.com/2011/11/20/nice-animations-with-time-managers-offset-feature/).
#
# In the following cell of this notebook, please enter the path to the folder containing the frame for .gif and .mp4 creation purpose. More infos for this step can be found [here](http://stackoverflow.com/questions/753190/programmatically-generate-video-or-animated-gif-in-python).

# %%
## Enter the path to the folder with maps frames from TimeManager Plug-in
user["map_frames_folder"]='/Users/taisgrippa/Dropbox/BROL/Mapathon_Tais/2018_gif/Time_manager/frames'

# %% [markdown]
# ## Create GIF

# %% [markdown]
# For creation of .gif output, please first install [imageio](https://github.com/imageio/imageio).

# %%
import imageio
import glob
frames = []
framepattern=user["map_frames_folder"]+"/*.png"
frames=glob.glob(framepattern)

# %%
from PIL import Image
from numpy import array
imagestack = []
for frame in frames:
    img = Image.open(frame)
    arr = array(img)
    imagestack.append(arr)
imageio.mimsave(user["map_frames_folder"]+'/Mapathon2016accomplishment.gif', imagestack, fps=4)
